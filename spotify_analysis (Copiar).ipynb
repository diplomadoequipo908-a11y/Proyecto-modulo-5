# %%
# Librerias
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import skew
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import ParameterSampler
from sklearn.preprocessing import StandardScaler, OneHotEncoder, PolynomialFeatures, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import RandomizedSearchCV
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
import tensorflow as tf
import shap 
plt.style.use('default')
pd.set_option('display.max_columns', None)
sns.set_theme(style="whitegrid")
plt.style.use("seaborn-v0_8-whitegrid")
# Out:
# 2026-06-18 14:43:10.262153: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-06-18 14:43:10.458266: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-06-18 14:43:10.458320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-06-18 14:43:10.488300: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-06-18 14:43:10.547210: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ...

# %%
# Data
url = "https://raw.githubusercontent.com/diplomadoequipo908-a11y/Proyecto-modulo-5/main/dataset.csv"
df = pd.read_csv(url).drop(columns=['Unnamed: 0'])

# %% [markdown]
# # Diccionario de datos
# | Column | Type | Range | Description |
# |---|---|---|---|
# | `track_id` | String | — | Unique Spotify URI identifier for the track |
# | `artists` | String | — | Performing artist name(s) |
# | `album_name` | String | — | Album the track belongs to |
# | `track_name` | String | — | Title of the track |
# | `popularity` | Integer | 0 – 100 | Spotify popularity score (higher = more popular) |
# | `duration_ms` | Integer | 0 – 5.2M | Track duration in milliseconds |
# | `explicit` | Boolean | True/False | Whether the track has explicit lyrics |
# | `danceability` | Float | 0.0 – 1.0 | How suitable a track is for dancing |
# | `energy` | Float | 0.0 – 1.0 | Perceptual measure of intensity and activity |
# | `key` | Integer | 0 – 11 | Musical key (0=C, 1=C♯, 2=D … 11=B) |
# | `loudness` | Float | -49.5 – 4.5 | Overall loudness in decibels (dB) |
# | `mode` | Integer | 0 or 1 | Modality — 1 = Major, 0 = Minor |
# | `speechiness` | Float | 0.0 – 1.0 | Presence of spoken words in the track |
# | `acousticness` | Float | 0.0 – 1.0 | Confidence the track is acoustic |
# | `instrumentalness` | Float | 0.0 – 1.0 | Predicts whether a track has no vocals |
# | `liveness` | Float | 0.0 – 1.0 | Detects presence of a live audience |
# | `valence` | Float | 0.0 – 1.0 | Musical positiveness conveyed by the track |
# | `tempo` | Float | 0 – 243 | Estimated tempo in beats per minute (BPM) |
# | `time_signature` | Integer | 0 – 5 | Estimated time signature of the track |
# | `track_genre` | String | 114 classes | Genre label assigned to the track |

# %%
df.describe()
# Out:
#           popularity   duration_ms   danceability         energy  \
# count  114000.000000  1.140000e+05  114000.000000  114000.000000
# mean       33.238535  2.280292e+05       0.566800       0.641383
# std        22.305078  1.072977e+05       0.173542       0.251529
# min         0.000000  0.000000e+00       0.000000       0.000000
# 25%        17.000000  1.740660e+05       0.456000       0.472000
# 50%        35.000000  2.129060e+05       0.580000       0.685000
# 75%        50.000000  2.615060e+05       0.695000       0.854000
# max       100.000000  5.237295e+06       0.985000       1.000000
#
#                  key       loudness           mode    speechiness  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        5.309140      -8.258960       0.637553       0.084652
# std         3.559987       5.029337       0.480709       0.105732
# min         0.000000     -49.531000       0.000000       0.000000
# ...

# %% [markdown]
# # Duplicados

# %%
print(df["track_id"].duplicated().sum())
# Out:
# 24259

# %% [markdown]
# ##### Existen  track_id duplicados, por lo que podemos observar que una cancion pjuede pertenecer a varios generos. Se creará una variable para cuantificar el número de generos por canción y se quitarán duplicados.

# %%
df["genres_per_song"] = (
    df.groupby("track_id")["track_genre"]
      .transform("nunique")
)
df.drop_duplicates(subset='track_id',keep='first',inplace=True)

# %% [markdown]
# # Valores nulos

# %%
missing = df.isnull().sum().sort_values(ascending=False)
print(missing)
# Out:
# album_name          1
# track_name          1
# artists             1
# track_id            0
# speechiness         0
# track_genre         0
# time_signature      0
# tempo               0
# valence             0
# liveness            0
# instrumentalness    0
# acousticness        0
# loudness            0
# mode                0
# key                 0
# energy              0
# danceability        0
# explicit            0
# duration_ms         0
# popularity          0
# genres_per_song     0
# dtype: int64

# %%
# Rellenar valores nulos con Unknown
for col in ['track_name', 'album_name', 'artists']:
    if col in df.columns:
        df[col] = df[col].fillna('Unknown')

# %% [markdown]
# # Re escalamiento de duración

# %%
df['duration_ms'] = np.log1p(df['duration_ms'])

# %% [markdown]
# # Análisis Exploratiorio

# %%
num_features = ['duration_ms','danceability','energy','loudness','speechiness','acousticness','instrumentalness','liveness','valence','tempo']

df[num_features].hist(
    bins=30,
    figsize=(18,14)
)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Distribución de popularidad

# %%
plt.figure(figsize=(20,10))
sns.histplot(df['popularity'], bins=100, kde=True,color='green')
plt.title('Popularity Distribution')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)
plt.show()

# %%
print(f"Mean: {df['popularity'].mean():.2f}")
print(f"Median: {df['popularity'].median():.2f}")
print(f"Skewness: {skew(df['popularity']):.3f}")
# Out:
# Mean: 33.20
# Median: 33.00
# Skewness: 0.071

# %% [markdown]
# ### La popularidad es aproximadamente simétrica, no dominada por valores extremos.

# %% [markdown]
# # Canciones populares vs no populares

# %%
popular = df[df['popularity'] >= 75]

unpopular = df[df['popularity'] <= 25]

plt.figure(figsize=(20,10))
sns.histplot(popular['popularity'], bins=20, kde=True,color='green')
plt.title('Popular Distribution (Popularity>75)')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)
plt.show()

plt.figure(figsize=(20,10))
sns.histplot(unpopular['popularity'], bins=20, kde=True,color='green')
plt.title('Unpopular Distribution (Popularity<25)')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# # Top 20 géneros

# %%
plt.figure(figsize=(20,8))
top_genres = (
    df['track_genre']
    .value_counts()
    .head(20)
)
ax = sns.barplot(x=top_genres.index,y=top_genres.values)

for i, v in enumerate(top_genres.values):
    ax.text(
        i,
        v + 10,
        str(v),
        ha='center',
        fontsize=9
    )

plt.title("Top 20 géneros")
plt.xlabel("Género")
plt.ylabel("Conteo")
plt.xticks(rotation=45)
plt.grid(axis='y', alpha=0.3)
plt.show()

# %% [markdown]
# ## Popularidad promedio por género

# %%
genre_popularity = (
    df.groupby('track_genre')['popularity']
    .mean()
    .sort_values(ascending=False)
)

top_20 = genre_popularity.head(20)

plt.figure(figsize=(18,8))
ax = top_20.plot(kind='bar')
for i, v in enumerate(top_20.values):
    ax.text(
        i,
        v + 0.5,
        f'{v:.1f}',
        ha='center',
        fontsize=9
    )
plt.title("Top géneros por popularidad promedio")
plt.ylabel("Popularidad promedio")
plt.xticks(rotation=45)
plt.grid(
    axis='y',
    linestyle='--',
    alpha=0.5
)
plt.show()

# %% [markdown]
# ##### Looking at the most common genres and the genres with the highest average popularity, it's clear that having more songs in the dataset does not necessarily mean a genre is more popular. Some genres appear very frequently simply because they have a large catalog, but their average popularity remains relatively low. On the other hand, several genres with fewer songs achieve much higher popularity scores on average, suggesting they generate stronger listener engagement. This indicates that genre frequency alone is not enough to understand what drives popularity, and that average popularity provides a better view of which genres tend to perform well with audiences.

# %% [markdown]
# # Correlación

# %%
numeric_df = df.select_dtypes(include=np.number)
plt.figure(figsize=(14,10))
sns.heatmap(numeric_df.corr(), cmap='coolwarm', annot=True)
plt.title('Matriz de correlación')
plt.show()

# %% [markdown]
# # Correlación con popularidad

# %%
corr_popularity = (
    df.select_dtypes(include=np.number)
      .corr()['popularity']
      .drop('popularity')
      .sort_values(ascending=False)
)

print(corr_popularity)

plt.figure(figsize=(10,6))
corr_popularity.plot(kind='barh')
plt.title("Correlación con popularidad")
plt.xlabel("Correlación de pearson")
plt.ylabel("Features")
plt.show()
# Out:
# loudness            0.071676
# danceability        0.064281
# time_signature      0.036893
# duration_ms         0.017802
# energy              0.013728
# genres_per_song     0.011339
# tempo               0.007270
# key                 0.003432
# valence            -0.011526
# liveness           -0.013844
# mode               -0.016214
# acousticness       -0.038847
# speechiness        -0.047081
# instrumentalness   -0.127465
# Name: popularity, dtype: float64

# %% [markdown]
# ##### El análisis de correlación indica que ninguna de las variables de audio individuales presenta una relación lineal significativa con la popularidad de la canción. Aunque algunas características muestran correlaciones positivas o negativas débiles, su magnitud es insuficiente para concluir que la popularidad pueda explicarse a partir de un único atributo de forma aislada.
# ##### Este comportamiento sugiere que la popularidad está determinada por relaciones más complejas, que probablemente involucran combinaciones de variables, efectos asociados al género musical y posibles interacciones no lineales entre las características.
# ##### En consecuencia, este hallazgo motiva el uso de modelos capaces de capturar este tipo de dinámica, como XGBoost y redes neuronales, ya que estos enfoques tienen mayor capacidad para modelar dependencias no lineales y efectos de interacción, lo que se traduce típicamente en un mejor desempeño predictivo frente a modelos lineales tradicionales.

# %% [markdown]
# ## Feature engineering

# %%
# Copia del df para feature engineering
df_fe = df.copy()
df_fe["artist_list"] = (df_fe["artists"].str.split(";").apply(
    lambda x: [a.strip() for a in x]))
# Número de srtistas colaborando en una canción
df_fe["num_artists"] = df_fe["artist_list"].apply(len)

# %% [markdown]
# ##### El feature engineering basado en estadísticas por género se aplicará después del train-test split para evitar data leakage. Estas transformaciones dependen de información agregada del conjunto de datos, por lo que, si se calcularan usando todo el dataset, incorporarían información del conjunto de prueba en el entrenamiento.
# ##### Para mantener una evaluación realista, las estadísticas se calcularon únicamente sobre el conjunto de entrenamiento y luego se aplicaron al resto de los datos. Esto asegura que el modelo no tenga acceso a información futura y que las métricas reflejen correctamente su capacidad de generalización.

# %% [markdown]
# ## Regresión linear, Ridge, Lasso, ElasticNet y Polinómica

# %%
audio_cols = [
    'danceability','energy','loudness','speechiness',
    'acousticness','instrumentalness','liveness',
    'valence','tempo'
]

results = []

datasets = {
    "Baseline": df,
    "Feature Engineering": df_fe
}

for dataset_name, dataset in datasets.items():

    print("\n" + "="*80)
    print(dataset_name)
    print("="*80)

    df_model = dataset.drop(
        columns=[
            "track_id","track_name","album_name",
            "artists","artist_list","time_signature"
        ],
        errors="ignore"
    )

    df_model["explicit"] = df_model["explicit"].astype(int)
    df_model["key"] = df_model["key"].astype(str)

    X = df_model.drop("popularity", axis=1)
    y = df_model["popularity"]

    cat_features = ["key", "track_genre"]

    # split FIRST
    X_train, X_test, y_train, y_test = train_test_split(
        X, y, test_size=0.20, random_state=42
    )

    # feature engineering AFTER split
    if dataset_name == "Feature Engineering":

        X_train_base = X_train.copy()
        X_test_base = X_test.copy()

        genre_means = X_train_base.groupby("track_genre")[audio_cols].mean()

        def add_genre_features(df):
            df = df.merge(
                genre_means,
                how='left',
                on='track_genre',
                suffixes=('', '_genre_avg')
            )

            for col in audio_cols:
                df[f"{col}_minus_genre_avg"] = df[col] - df[f"{col}_genre_avg"]

            return df.fillna(0)

        X_train = add_genre_features(X_train_base)
        X_test = add_genre_features(X_test_base)

    # update feature lists AFTER FE
    num_features = [
        col for col in X_train.columns
        if col not in cat_features
    ]

    # preprocessors
    base_preprocessor = ColumnTransformer([
        ("num", StandardScaler(), num_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
    ])

    poly_preprocessor = ColumnTransformer([
        (
            "num",
            Pipeline([
                ("scale", StandardScaler()),
                ("poly", PolynomialFeatures(
                    degree=2,
                    include_bias=False,
                    interaction_only=True
                ))
            ]),
            num_features
        ),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
    ])

    models = {
        "Linear": (base_preprocessor, LinearRegression()),
        "Ridge": (base_preprocessor, Ridge(alpha=1.0)),
        "Lasso": (base_preprocessor, Lasso(alpha=0.01, max_iter=10000)),
        "ElasticNet": (
            base_preprocessor,
            ElasticNet(alpha=0.01, l1_ratio=0.5, max_iter=10000)
        ),
        "Polynomial_Ridge": (poly_preprocessor, Ridge(alpha=10.0))
    }

    for model_name, (prep, model) in models.items():

        print("\nmodel:", model_name)

        pipe = Pipeline([
            ("prep", prep),
            ("model", model)
        ])

        pipe.fit(X_train, y_train)

        preds = pipe.predict(X_test)

        mae = mean_absolute_error(y_test, preds)
        rmse = np.sqrt(mean_squared_error(y_test, preds))
        r2 = r2_score(y_test, preds)

        results.append({
            "Dataset": dataset_name,
            "Model": model_name,
            "MAE": mae,
            "RMSE": rmse,
            "R2": r2
        })

        print(f"mae: {mae:.4f} | rmse: {rmse:.4f} | r2: {r2:.4f}")

        # sampling for clearer plots
        sample_size = min(2000, len(y_test))
        idx = np.random.choice(len(y_test), sample_size, replace=False)

        y_plot = y_test.iloc[idx]
        preds_plot = preds[idx]
        residuals = y_plot - preds_plot

        fig, axes = plt.subplots(1, 3, figsize=(18, 5))

        # predicted vs actual
        sns.scatterplot(x=y_plot, y=preds_plot, alpha=0.3, ax=axes[0])
        axes[0].plot(
            [y_plot.min(), y_plot.max()],
            [y_plot.min(), y_plot.max()],
            "r--",
            linewidth=2
        )
        axes[0].set_title(f"predicted vs actual (r2={r2:.3f})")

        # residuals
        sns.scatterplot(x=preds_plot, y=residuals, alpha=0.3, ax=axes[1])
        axes[1].axhline(0, color="red", linestyle="--")
        axes[1].set_title("residuals")

        # error distribution
        sns.histplot(residuals, bins=40, kde=True, ax=axes[2])
        axes[2].axvline(0, color="red", linestyle="--")
        axes[2].set_title("error distribution")

        plt.suptitle(f"{dataset_name} | {model_name}")
        plt.tight_layout()
        plt.show()

# final comparison
comparison = pd.DataFrame(results).sort_values("R2", ascending=False)

print("\n" + "="*100)
print("regression comparison")
print("="*100)
print(comparison)
# Out:
# ...
# Baseline
# ...
#
# model: Linear
# mae: 12.0365 | rmse: 16.8107 | r2: 0.3234
# model: Ridge
# mae: 12.0394 | rmse: 16.8105 | r2: 0.3234
# model: Lasso
# mae: 12.2345 | rmse: 16.8348 | r2: 0.3215
# model: ElasticNet
# mae: 13.3181 | rmse: 17.3292 | r2: 0.2810
# model: Polynomial_Ridge
# mae: 12.0445 | rmse: 16.7505 | r2: 0.3283
# ...
# Feature Engineering
# ...
#
# model: Linear
# mae: 12.0363 | rmse: 16.8105 | r2: 0.3234
# model: Ridge
# mae: 12.0385 | rmse: 16.8102 | r2: 0.3235
# model: Lasso
# mae: 12.1960 | rmse: 16.8384 | r2: 0.3212
# model: ElasticNet
# mae: 13.0018 | rmse: 17.2164 | r2: 0.2904
# model: Polynomial_Ridge
# mae: 11.8909 | rmse: 16.6030 | r2: 0.3400
# ...
# regression comparison
# ...
#                Dataset             Model        MAE       RMSE        R2
# 9  Feature Engineering  Polynomial_Ridge  11.890865  16.603049  0.340035
# 4             Baseline  Polynomial_Ridge  12.044477  16.750525  0.328259
# 6  Feature Engineering             Ridge  12.038545  16.810229  0.323462
# ...

# %% [markdown]
# ##### El análisis de los modelos de regresión muestra que, en general, los enfoques lineales presentan un desempeño limitado para este problema, con valores de R2 alrededor de 0.32–0.34, lo que indica que solo una proporción moderada de la variabilidad en la popularidad puede ser explicada bajo supuestos lineales.
# ##### La incorporación de feature engineering basado en contexto (promedios por género y desviaciones) produce mejoras consistentes, aunque moderadas, en la mayoría de los modelos. Este efecto es más evidente en el modelo Polynomial Ridge, que alcanza el mejor desempeño con un R2 de aproximadamente 0.34, sugiriendo que la inclusión de interacciones y transformaciones no lineales aporta información adicional relevante.
# ##### Sin embargo, incluso en el mejor escenario, la mejora respecto al baseline es relativamente acotada, lo que sugiere que la estructura subyacente del problema no puede capturarse adecuadamente mediante relaciones lineales simples ni mediante extensiones polinomiales de baja complejidad. Asimismo, modelos como Lasso y ElasticNet presentan un rendimiento inferior, lo que indica que la regularización fuerte y la selección automática de variables tienden a eliminar información útil en un contexto donde las señales ya son débiles y distribuidas.
# ##### En conjunto, estos resultados refuerzan la hipótesis inicial: la popularidad de las canciones está determinada por patrones complejos, probablemente no lineales y dependientes del contexto, que exceden la capacidad expresiva de los modelos lineales tradicionales. Esto justifica el uso de enfoques más flexibles como XGBoost o redes neuronales, que están mejor diseñados para capturar interacciones complejas y relaciones no lineales entre variables.

# %% [markdown]
# ## XGB with Parameter Grid

# %%
# mae vs rmse
configs = {
    'RMSE': {
        'objective': 'reg:squarederror',
        'eval_metric': 'rmse'
    },
    'MAE': {
        'objective': 'reg:absoluteerror',
        'eval_metric': 'mae'
    }
}

# Parameter Grid
param_dist = {
    'max_depth': [5,6,7,8,9],
    'learning_rate': [0.01,0.02,0.03,0.05],
    'min_child_weight': [1,3,5],
    'subsample': [0.7,0.8,0.9],
    'colsample_bytree': [0.7,0.8,0.9],
    'reg_lambda': [0.5,1,2,5],
    'reg_alpha': [0,0.05,0.1,0.5],
    'gamma': [0,0.1,0.3]
}

audio_cols = [
    'danceability','energy','loudness','speechiness',
    'acousticness','instrumentalness','liveness',
    'valence','tempo'
]

xgb_results = []

for dataset_name, dataset in datasets.items():

    print(f"\n{'='*80}")
    print(f"XGBOOST - {dataset_name}")
    print(f"{'='*80}")

    df_model = dataset.drop(
        columns=[
            "track_id","track_name","album_name",
            "artists","artist_list","time_signature"
        ],
        errors="ignore"
    )

    df_model["explicit"] = df_model["explicit"].astype(int)
    df_model["key"] = df_model["key"].astype(str)

    X = df_model.drop("popularity", axis=1)
    y = df_model["popularity"]

    cat_features = ["key", "track_genre"]

    # Train/test split
    X_train_full, X_test, y_train_full, y_test = train_test_split(
        X, y, test_size=0.20, random_state=42
    )

    X_train, X_val, y_train, y_val = train_test_split(
        X_train_full, y_train_full, test_size=0.20, random_state=42
    )

    # Feature engineering 
    if dataset_name == "Feature Engineering":

        X_train_base = X_train.copy()
        X_val_base = X_val.copy()
        X_test_base = X_test.copy()

        genre_means = X_train_base.groupby("track_genre")[audio_cols].mean()

        def add_genre_features(df):
            df = df.merge(
                genre_means,
                how='left',
                on='track_genre',
                suffixes=('', '_genre_avg')
            )
            for col in audio_cols:
                df[f"{col}_minus_genre_avg"] = df[col] - df[f"{col}_genre_avg"]
            return df.fillna(0)

        X_train = add_genre_features(X_train_base)
        X_val = add_genre_features(X_val_base)
        X_test = add_genre_features(X_test_base)

    # Preprocessing
    preprocessor = ColumnTransformer(
        [('cat', OneHotEncoder(handle_unknown='ignore'), cat_features)],
        remainder='passthrough'
    )

    X_train_enc = preprocessor.fit_transform(X_train)
    X_val_enc = preprocessor.transform(X_val)
    X_test_enc = preprocessor.transform(X_test)

    param_list = list(ParameterSampler(param_dist, n_iter=8, random_state=42))

    # Loop for loss functions
    for model_name, cfg in configs.items():

        print(f"\nModel: {model_name}")

        best_score = float("inf")
        best_model = None
        best_params = None

        for params in param_list:

            model = XGBRegressor(
                n_estimators=3000,
                objective=cfg['objective'],
                eval_metric=cfg['eval_metric'],
                early_stopping_rounds=20,
                tree_method='hist',
                random_state=42,
                n_jobs=-1,
                **params
            )

            model.fit(
                X_train_enc,
                y_train,
                eval_set=[(X_val_enc, y_val)],
                verbose=False
            )

            val_preds = model.predict(X_val_enc)

            # Scoring
            if model_name == "MAE":
                score = mean_absolute_error(y_val, val_preds)
            else:
                score = np.sqrt(mean_squared_error(y_val, val_preds))

            if score < best_score:
                best_score = score
                best_model = model
                best_params = params

        print("Best params:", best_params)

        # Evaluation
        test_preds = best_model.predict(X_test_enc)

        mae = mean_absolute_error(y_test, test_preds)
        rmse = np.sqrt(mean_squared_error(y_test, test_preds))
        r2 = r2_score(y_test, test_preds)

        print(f"Best Iteration: {best_model.best_iteration}")
        print(f"MAE: {mae:.4f} | RMSE: {rmse:.4f} | R2: {r2:.4f}")

        xgb_results.append({
            "Dataset": dataset_name,
            "Model": f"XGB_{model_name}",
            "MAE": mae,
            "RMSE": rmse,
            "R2": r2
        })

        # SHAP for RMSE
        if model_name == "RMSE":

            print("\nRunning SHAP...")

            feature_names = preprocessor.get_feature_names_out()

            sample_size = min(500, X_test_enc.shape[0])
            idx = np.random.choice(X_test_enc.shape[0], sample_size, replace=False)

            X_sample = X_test_enc[idx]

            if hasattr(X_sample, 'toarray'):
                X_sample = X_sample.toarray()

            X_sample = pd.DataFrame(X_sample, columns=feature_names)

            explainer = shap.Explainer(best_model.predict, X_sample)
            shap_values = explainer(X_sample)
            shap.summary_plot(shap_values, X_sample)
            
            #shap_importance = (
            #    pd.DataFrame({
            #        'Feature': feature_names,
            #        'Importance': np.abs(shap_values).mean(axis=0)
            #    })
            #    .sort_values('Importance', ascending=False)
            #)


            shap_importance = (
                pd.DataFrame({
                    'Feature': feature_names,
                    'Importance': np.abs(shap_values.values).mean(axis=0)
                })
                .sort_values('Importance', ascending=False)
            )
                    
            print("\nTop SHAP Features:")
            print(shap_importance.head(10))

            shap.summary_plot(shap_values, X_sample)
            shap.summary_plot(shap_values, X_sample, plot_type='bar')

# Comparison
xgb_comparison = pd.DataFrame(xgb_results).sort_values("R2", ascending=False)

print("\n" + "="*80)
print("XGBOOST COMPARISON")
print("="*80)
print(xgb_comparison)
# Out:
# ...
# XGBOOST - Baseline
# ...
#
# Model: RMSE
# Best params: {'subsample': 0.9, 'reg_lambda': 5, 'reg_alpha': 0.05, 'min_child_weight': 5, 'max_depth': 9, 'learning_rate': 0.02, 'gamma': 0.1, 'colsample_bytree': 0.9}
# Best Iteration: 2659
# MAE: 9.9816 | RMSE: 14.8098 | R2: 0.4749
#
# Running SHAP...
# PermutationExplainer explainer: 501it [01:36,  4.66it/s]
# Top SHAP Features:
#                          Feature  Importance
# 129          remainder__loudness    5.157355
# 128            remainder__energy    4.246586
# 131       remainder__speechiness    3.775826
# 134          remainder__liveness    3.608910
# 137   remainder__genres_per_song    3.116082
# 133  remainder__instrumentalness    3.050559
# 132      remainder__acousticness    3.026669
# 125       remainder__duration_ms    2.645164
# 127      remainder__danceability    2.076511
# 135           remainder__valence    1.751397
# Model: MAE
# ...

# %% [markdown]
# ##### El desempeño de XGBoost confirma de manera clara la hipótesis inicial sobre la naturaleza no lineal del problema. A diferencia de los modelos de regresión, XGBoost logra una mejora sustancial en la capacidad predictiva, alcanzando valores de R2R^2R2 cercanos a 0.49 en el mejor escenario, lo que representa un incremento significativo frente a los aproximadamente 0.34 obtenidos con modelos lineales.
# ##### El impacto del feature engineering basado en promedios por género y desviaciones relativas es consistente y positivo. En particular, el modelo optimizado con RMSE presenta una mejora clara al pasar de un R2R^2R2 de 0.477 en el baseline a 0.487 con feature engineering, lo que indica que el modelo es capaz de aprovechar de manera efectiva la información contextual introducida. Este resultado refuerza la idea de que las relaciones relevantes no dependen únicamente de valores absolutos, sino de la posición relativa de una canción dentro de su género.
# ##### Al comparar los objetivos de optimización, se observa un comportamiento esperado: los modelos entrenados con RMSE alcanzan mejores valores de R2R^2R2 y menor error cuadrático, mientras que los modelos optimizados con MAE logran ligeras mejoras en el error absoluto medio, pero a costa de una menor capacidad global de ajuste. Esto confirma que RMSE es más adecuado cuando el objetivo principal es maximizar la capacidad explicativa del modelo, especialmente en presencia de errores grandes que deben ser penalizados con mayor intensidad.
# ##### Desde una perspectiva metodológica, es importante destacar que no se utilizó validación cruzada (cross-validation) durante el proceso de ajuste de hiperparámetros. Esta decisión responde a restricciones de capacidad computacional, ya que el espacio de búsqueda definido y la complejidad del modelo habrían incrementado significativamente los tiempos de ejecución, haciendo el proceso impráctico. En su lugar, se optó por una estrategia basada en un conjunto de validación (train/validation split), que permitió un equilibrio razonable entre robustez y eficiencia.
# ##### Asimismo, fue necesario ajustar el proceso de tuning para adaptarse a las limitaciones de tiempo de ejecución. En particular, se redujo el número de iteraciones en la búsqueda aleatoria de hiperparámetros, el número máximo de árboles y los criterios de early stopping. Estas decisiones permitieron mantener un proceso de optimización suficientemente riguroso, sin incurrir en costos computacionales excesivos, asegurando al mismo tiempo la obtención de resultados consistentes y comparables.
# ### SHAP
# ##### Los cambios observados en la importancia de las variables según SHAP entre el modelo baseline y el modelo con feature engineering son esperables y responden a una redistribución de la información predictiva entre las variables.
# ##### En el modelo baseline, las variables categóricas, como el género de la canción, dominan la importancia, ya que proporcionan información contextual clave. Sin embargo, tras la incorporación de variables relativas al género, parte de ese contexto queda codificado dentro de variables numéricas, lo que reduce la dependencia del modelo en divisiones basadas únicamente en categorías.
# ##### Como resultado, la importancia se distribuye entre variables originales y variables generadas, reflejando una representación más rica, estructurada y matizada de los datos.
# ##### En conjunto, los resultados de XGBoost demuestran que los modelos de ensamble basados en árboles son especialmente adecuados para este problema, ya que capturan de forma eficiente interacciones complejas y relaciones no lineales entre variables. Esto los posiciona como una opción claramente superior frente a los modelos lineales tradicionales en este contexto.

# %% [markdown]
# ## NN

# %%
# seed
np.random.seed(42)
tf.keras.utils.set_random_seed(42)

# feature engineering
def add_genre_features(train_df, df, audio_cols):

    train_df = train_df.reset_index(drop=True)
    df = df.reset_index(drop=True)

    # remove existing features
    cols_to_drop = [c for c in df.columns if '_genre_avg' in c or '_minus_genre_avg' in c]
    df = df.drop(columns=cols_to_drop, errors='ignore')

    # compute means from train only
    genre_means = train_df.groupby("track_genre")[audio_cols].mean()

    # merge
    df = df.merge(
        genre_means,
        how='left',
        on='track_genre',
        suffixes=('', '_genre_avg')
    )

    # subtract averages
    for col in audio_cols:
        df[f"{col}_minus_genre_avg"] = df[col] - df[f"{col}_genre_avg"]

    return df.fillna(0)

# neural network class
class SpotifyEmbeddingNN:

    def __init__(self, loss_function="huber"):

        if loss_function == "huber":
            self.loss_function = tf.keras.losses.Huber(delta=10)
        else:
            self.loss_function = loss_function

        self.genre_encoder = LabelEncoder()
        self.key_encoder = LabelEncoder()
        self.scaler = StandardScaler()

    def build_model(self, input_dim, n_genres, n_keys):

        numeric_input = tf.keras.Input(shape=(input_dim,))
        genre_input = tf.keras.Input(shape=(1,))
        key_input = tf.keras.Input(shape=(1,))

        genre_emb = tf.keras.layers.Embedding(n_genres, 16)(genre_input)
        genre_emb = tf.keras.layers.Flatten()(genre_emb)

        key_emb = tf.keras.layers.Embedding(n_keys, 4)(key_input)
        key_emb = tf.keras.layers.Flatten()(key_emb)

        x = tf.keras.layers.Concatenate()([numeric_input, genre_emb, key_emb])
        x = tf.keras.layers.Dropout(0.1)(x)

        x = tf.keras.layers.Dense(128)(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.ReLU()(x)
        x = tf.keras.layers.Dropout(0.2)(x)

        x = tf.keras.layers.Dense(64)(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.ReLU()(x)
        x = tf.keras.layers.Dropout(0.15)(x)

        x = tf.keras.layers.Dense(32)(x)
        x = tf.keras.layers.BatchNormalization()(x)
        x = tf.keras.layers.ReLU()(x)

        output = tf.keras.layers.Dense(1)(x)

        model = tf.keras.Model(
            inputs=[numeric_input, genre_input, key_input],
            outputs=output
        )

        model.compile(
            optimizer=tf.keras.optimizers.Adam(0.001),
            loss=self.loss_function,
            metrics=["mae", "mse"]
        )

        return model

    def fit(self, X_train, y_train, X_val, y_val):

        X_train = X_train.copy()
        X_val = X_val.copy()

        # encode
        X_train["track_genre"] = self.genre_encoder.fit_transform(X_train["track_genre"].astype(str))
        X_val["track_genre"] = self.genre_encoder.transform(X_val["track_genre"].astype(str))

        X_train["key"] = self.key_encoder.fit_transform(X_train["key"].astype(str))
        X_val["key"] = self.key_encoder.transform(X_val["key"].astype(str))

        self.num_cols = [c for c in X_train.columns if c not in ["track_genre", "key"]]

        X_train_num = self.scaler.fit_transform(X_train[self.num_cols])
        X_val_num = self.scaler.transform(X_val[self.num_cols])

        self.model = self.build_model(
            X_train_num.shape[1],
            len(self.genre_encoder.classes_),
            len(self.key_encoder.classes_)
        )

        self.history = self.model.fit(
            [X_train_num, X_train["track_genre"], X_train["key"]],
            y_train,
            validation_data=(
                [X_val_num, X_val["track_genre"], X_val["key"]],
                y_val
            ),
            epochs=200,
            batch_size=1024,
            callbacks=[
                tf.keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)
            ],
            verbose=1
        )

    def predict(self, X):

        X = X.copy()

        X["track_genre"] = self.genre_encoder.transform(X["track_genre"].astype(str))
        X["key"] = self.key_encoder.transform(X["key"].astype(str))

        X_num = self.scaler.transform(X[self.num_cols])

        preds = self.model.predict(
            [X_num, X["track_genre"], X["key"]],
            verbose=0
        )

        return preds.flatten()

    def evaluate(self, X, y):

        preds = self.predict(X)

        mae = mean_absolute_error(y, preds)
        rmse = np.sqrt(mean_squared_error(y, preds))
        r2 = r2_score(y, preds)

        return {"MAE": mae, "RMSE": rmse, "R2": r2}

    def plot_history(self):

        history = self.history.history

        plt.figure(figsize=(12,5))

        # loss
        plt.subplot(1,2,1)
        plt.plot(history["loss"])
        plt.plot(history["val_loss"])
        plt.title("loss")
        plt.legend(["train","val"])

        # mae
        plt.subplot(1,2,2)
        plt.plot(history["mae"])
        plt.plot(history["val_mae"])
        plt.title("mae")
        plt.legend(["train","val"])

        plt.show()


# Evaluate

audio_cols = [
    'danceability','energy','loudness','speechiness',
    'acousticness','instrumentalness','liveness',
    'valence','tempo'
]

losses = ["mse", "mae", "huber"]

results_nn = []

best_model = None
best_score = np.inf

for use_fe in [False, True]:

    dataset_name = "Feature Engineering" if use_fe else "Baseline"

    for loss in losses:

        print("\n" + "="*70)
        print(f"nn - {dataset_name} - loss: {loss}")
        print("="*70)

        # copies
        X_train_base = X_train.copy()
        X_val_base = X_val.copy()
        X_test_base = X_test.copy()

        X_train_tmp = X_train_base.copy()
        X_val_tmp = X_val_base.copy()
        X_test_tmp = X_test_base.copy()

        # feature engineering
        if use_fe:
            X_train_tmp = add_genre_features(X_train_base, X_train_tmp, audio_cols)
            X_val_tmp = add_genre_features(X_train_base, X_val_tmp, audio_cols)
            X_test_tmp = add_genre_features(X_train_base, X_test_tmp, audio_cols)

        # model
        nn = SpotifyEmbeddingNN(loss_function=loss)

        nn.fit(X_train_tmp, y_train, X_val_tmp, y_val)

        metrics = nn.evaluate(X_test_tmp, y_test)

        print(metrics)

        results_nn.append({
            "Dataset": dataset_name,
            "Model": f"NN_{loss.upper()}",
            "MAE": metrics["MAE"],
            "RMSE": metrics["RMSE"],
            "R2": metrics["R2"]
        })

        # best model selection
        if metrics["RMSE"] < best_score:
            best_score = metrics["RMSE"]
            best_model = nn


# final results
comparison_nn = pd.DataFrame(results_nn).sort_values("R2", ascending=False)

print("\n" + "="*80)
print("nn comparison")
print("="*80)
print(comparison_nn)

# plot best training history
best_model.plot_history()
# Out:
# ...
# nn - Baseline - loss: mse
# ...
# Epoch 1/200
# 57/57 [==============================] - 2s 11ms/step - loss: 1411.0155 - mae: 31.9862 - mse: 1411.0155 - val_loss: 1491.8175 - val_mae: 33.0149 - val_mse: 1491.8175
# Epoch 2/200
# 57/57 [==============================] - 0s 7ms/step - loss: 1280.1116 - mae: 30.6864 - mse: 1280.1116 - val_loss: 1231.7557 - val_mae: 30.1490 - val_mse: 1231.7557
# Epoch 3/200
# 57/57 [==============================] - 0s 7ms/step - loss: 1137.8070 - mae: 28.9792 - mse: 1137.8070 - val_loss: 954.7491 - val_mae: 26.4535 - val_mse: 954.7491
# Epoch 4/200
# 57/57 [==============================] - 0s 7ms/step - loss: 1006.3708 - mae: 27.2498 - mse: 1006.3708 - val_loss: 818.2726 - val_mae: 24.3344 - val_mse: 818.2726
# Epoch 5/200
# 57/57 [==============================] - 0s 7ms/step - loss: 888.9606 - mae: 25.5349 - mse: 888.9606 - val_loss: 735.5472 - val_mae: 22.8090 - val_mse: 735.5472
# Epoch 6/200
# ...

# %%
print(comparison_nn)
# Out:
#                Dataset     Model        MAE       RMSE        R2
# 3  Feature Engineering    NN_MSE  10.651654  15.522727  0.423126
# 0             Baseline    NN_MSE  10.512713  15.529478  0.422624
# 2             Baseline  NN_HUBER   9.746267  16.223023  0.369901
# 5  Feature Engineering  NN_HUBER   9.918169  16.406297  0.355584
# 1             Baseline    NN_MAE   9.676060  16.733639  0.329612
# 4  Feature Engineering    NN_MAE   9.779966  16.812642  0.323267

# %% [markdown]
# ##### Los resultados obtenidos con la red neuronal muestran una mejora con respecto a los modelos de regresión lineales, aunque no alcanzan el nivel de desempeño de XGBoost. Esto sugiere que, si bien la red neuronal es capaz de capturar relaciones no lineales y patrones más complejos en los datos, su eficiencia en este tipo de datos tabulares es inferior a la de modelos basados en árboles.
# ##### Desde el punto de vista arquitectónico, se diseñó una red neuronal relativamente poco profunda, compuesta por tres capas densas de tamaños decrecientes (128, 64 y 32 neuronas), acompañadas de normalización (batch normalization) y regularización (dropout). Esta estructura responde a las buenas prácticas en modelado sobre datos tabulares, donde redes muy profundas tienden a sobreajustar sin aportar mejoras significativas. La reducción progresiva del número de neuronas permite que el modelo comprima la información de forma gradual, favoreciendo la generalización y evitando la propagación de ruido.
# ##### Adicionalmente, se incorporaron embeddings para las variables categóricas track_genre y key, lo que permite al modelo aprender representaciones densas de estas categorías en lugar de depender de codificaciones dispersas como el one-hot encoding. Esta decisión es especialmente importante, dado que el género musical es una variable con un fuerte efecto contextual, y su representación como embedding facilita la captura de similitudes y relaciones entre diferentes géneros.
# ##### La inclusión de batch normalization contribuye a estabilizar el entrenamiento al reducir el cambio en la distribución de las activaciones, mientras que el uso de dropout introduce regularización, mitigando el riesgo de sobreajuste en un modelo con alta capacidad. Por otro lado, el uso de optimizadores modernos como Adam, junto con early stopping y reducción adaptativa de la tasa de aprendizaje, permite un proceso de entrenamiento eficiente y controlado.
# ##### En cuanto a la función de pérdida, el análisis de MAE, MSE y Huber confirma los comportamientos esperados: MSE tiende a maximizar el R2 al penalizar más fuertemente los errores grandes, MAE ofrece mayor robustez frente a outliers, y Huber proporciona un equilibrio entre ambos. Sin embargo, las diferencias en desempeño entre estas funciones son moderadas, lo que sugiere que la limitación principal no reside en la función de pérdida, sino en la naturaleza de los datos y el tipo de modelo.
# ##### En conjunto, los resultados indican que, aunque la red neuronal es capaz de modelar relaciones no lineales y aprovechar el feature engineering contextual, su desempeño en datos tabulares estructurados queda por debajo del obtenido por XGBoost. Esto es consistente con la evidencia empírica en machine learning, donde los modelos basados en árboles suelen ser más eficientes en este tipo de problemas debido a su capacidad inherente para capturar interacciones y segmentaciones complejas sin requerir una arquitectura profunda.

# %% [markdown]
# # Gráficas de aprendizaje
#
#
# Esta sección nos demuestra si nuestro modelo memorizó o aprendió conforme a los datos de popularidad. Además, podemos visualizar si esto depende de

# %%
print("Tipo de best_model:", type(best_model))
print("Best_model:", best_model)
# Out:
# Tipo de best_model: <class '__main__.SpotifyEmbeddingNN'>
# Best_model: <__main__.SpotifyEmbeddingNN object at 0x79d59261fc50>

# %% [markdown]
# ## Curva de Aprendizaje XGB-RMSE

# %% [markdown]
# Dada la gráfica de learning-curve, tenemos que:
#
# * Hay un bias alto en el train $RMSE\approx 16.5$, pero se empiza a estabilizar en $Val RMSE\appox17$. Por ende, no depende   de la cantidad de datos (no requiere más datos).
#
# * No hay overfitting, porque las líneas no se separan mucho y el gap entre _Train_ y _Val_ es de $\approx0.5$

# %%
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
import numpy as np

def plot_learning_curve(model, X, y, preprocessor, title="Learning Curve"):
    # Transforma y convierte sparse a dense
    X_enc = preprocessor.fit_transform(X)
    if hasattr(X_enc, "toarray"):
        X_enc = X_enc.toarray()
    
    train_sizes, train_scores, val_scores = learning_curve(
        estimator=model,
        X=X_enc,
        y=y,
        train_sizes=np.linspace(0.1, 1.0, 10),
        cv=5,
        scoring='neg_mean_squared_error',
        n_jobs=-1,
        shuffle=True,
        random_state=42
    )
    
    train_rmse = np.sqrt(-train_scores)
    val_rmse = np.sqrt(-val_scores)
    
    plt.figure(figsize=(8, 5))
    plt.plot(train_sizes, train_rmse.mean(axis=1), 'o-', color='blue', label='Train RMSE')
    plt.plot(train_sizes, val_rmse.mean(axis=1), 'o-', color='red', label='Validation RMSE')
    plt.fill_between(train_sizes, train_rmse.mean(axis=1) - train_rmse.std(axis=1), 
                     train_rmse.mean(axis=1) + train_rmse.std(axis=1), alpha=0.1, color='blue')
    plt.fill_between(train_sizes, val_rmse.mean(axis=1) - val_rmse.std(axis=1), 
                     val_rmse.mean(axis=1) + val_rmse.std(axis=1), alpha=0.1, color='red')
    
    plt.xlabel('Training Set Size')
    plt.ylabel('RMSE')
    plt.title(title)
    plt.legend(loc='best')
    plt.grid(True)
    plt.show()


# best_params y best_model_original es XGBRegressor
best_xgb = XGBRegressor(**best_params, random_state=42, n_jobs=-1)

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('model', best_xgb)
])

# pipeline.fit entrena los datos x_train_full  y y_train_full
pipeline.fit(X_train_full, y_train_full)

# llama la función con el modelo dentro del pipeline usando el modelo
#pipeline.named_steps['model']
plot_learning_curve(
    model=pipeline.named_steps['model'],
    X=X_train_full,
    y=y_train_full,
    preprocessor=preprocessor,
    title="Learning Curve - XGB RMSE"
)

# %% [markdown]
# ## Curva de validación

# %% [markdown]
# Con base a la curva de validación tenemos las siguientes conclusiones:
#
# * El $\mathbf{Train}$  $\mathbf{RMSE}$ baja linealmente hasta $\approx 12$ con $\mathbf{depth} =20$, por ende el modelo si puede memorizar.
#
# * Tenemos que $\mathbf{Validation}$ $\mathbf{RMSE}$ oscila de $18.5-15.5$, aunque se va aplanando a partir de $15.5$.
#
# * El $\mathbf{Gap}$ $\mathbf{train-val}$ se abre conforme aumentas el $\mathbf{depth}$. Por lo que, vemos un _overfitting_ pequeño entre $12-15.5$.

# %%
from sklearn.model_selection import validation_curve

param_range = [3, 5, 7, 10, 15, 20]
train_scores, val_scores = validation_curve(
    estimator=pipeline,
    X=X_train_full, y=y_train_full,
    param_name='model__max_depth',  # nota los 2 guiones
    param_range=param_range,
    cv=5, scoring='neg_mean_squared_error', n_jobs=-1
)

train_rmse = np.sqrt(-train_scores).mean(axis=1)
val_rmse = np.sqrt(-val_scores).mean(axis=1)

plt.plot(param_range, train_rmse, label='Train')
plt.plot(param_range, val_rmse, label='Validation')
plt.xlabel('max_depth'); plt.ylabel('RMSE'); plt.legend() 
plt.show()

# %% [markdown]
# ## Gráfica de residuos

# %% [markdown]
# Tenemos lo siguiente de la gráfica de residuos:
#
# * Se forma un embudo, porque los residuales no están distribuidos leatoriamente alrededor del $0$.
#
# * Hay un sesgo en predicciones altas; si $\mathbf{Pred}>50$, sus residuales son negativos, por ende no toma canciones demasiado populares.

# %%
y_pred = pipeline.predict(X_train_full)
residuals = y_train_full - y_pred

plt.scatter(y_pred, residuals, alpha=0.3)
plt.axhline(0, color='red', linestyle='--')
plt.xlabel('Predicho'); plt.ylabel('Residuos')
plt.title('Gráfica de Residuos') 
plt.show()
